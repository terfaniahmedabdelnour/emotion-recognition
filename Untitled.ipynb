# %%
from keras.models import load_model
from time import sleep
from keras.preprocessing.image import img_to_array
from keras.preprocessing import image
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
classifier = load_model('model.h5')

emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

cap = cv2.VideoCapture(0)

# Liste pour stocker les émotions détectées
detected_emotions = []

while True:
    _, frame = cap.read()
    labels = []
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 255), 2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_gray = cv2.resize(roi_gray, (48, 48), interpolation=cv2.INTER_AREA)

        if np.sum([roi_gray]) != 0:
            roi = roi_gray.astype('float')/255.0
            roi = img_to_array(roi)
            roi = np.expand_dims(roi, axis=0)

            prediction = classifier.predict(roi)[0]
            label = emotion_labels[prediction.argmax()]
            
            # Ajouter l'émotion détectée à la liste
            detected_emotions.append(label)
            
            label_position = (x, y)
            cv2.putText(frame, label, label_position, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        else:
            cv2.putText(frame, 'No Faces', (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    cv2.imshow('Emotion Detector', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# Afficher toutes les émotions détectées
print("Emotions détectées : ", detected_emotions)
# Out:
# C:\Users\T14S\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# C:\Users\T14S\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\base_optimizer.py:34: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 912ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# ...

# %%
len(detected_emotions)
# Out:
# 835

# %%
#detected_emotions

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.hist(detected_emotions, bins=len(emotion_labels), alpha=0.7, color='blue', edgecolor='black')
plt.title('Distribution des émotions détectées')
plt.xlabel('Émotions')
plt.ylabel('Nombre de fois détecté')
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder


label_encoder = LabelEncoder()
encoded_emotions = label_encoder.fit_transform(detected_emotions)

# Préparation des données pour le scatter plot
x = list(range(len(detected_emotions)))  # Indices des émotions
y = encoded_emotions  # Émotions encodées

# Créer le scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', edgecolor='black')
plt.title('Émotions détectées dans l\'ordre d\'apparition')
plt.xlabel('Index')
plt.ylabel('Émotions (encodées)')
plt.yticks(ticks=range(len(label_encoder.classes_)), labels=label_encoder.classes_)
plt.show()
